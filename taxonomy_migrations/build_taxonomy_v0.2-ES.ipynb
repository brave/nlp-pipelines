# %%
import pandas as pd

# %%
# this version of the taxonomy already has a month's world of crypto data (about 4k samples)

original_df = pd.read_csv('/run/user/1000/gvfs/smb-share:server=index.local,share=datasets/taxonomy/spanish_training_df.csv.gz')

# %%
original_df
# Out:
#         Unnamed: 0                                                url  \
# 0              694  https://www.arquimaster.com.ar/web/como-pintar...
# 1              631  https://www.archdaily.pe/pe/884891/dipoli-edif...
# 2              822  https://www.paisajetransversal.org/2016/09/enc...
# 3              846  https://www.plataformaarquitectura.cl/cl/02-13...
# 4              169     http://noticias.arq.com.mx/Detalles/21261.html
# 5              627  https://www.archdaily.mx/mx/804947/materiales-...
# 6              834  https://www.plataformaarquitectura.cl/cl/02-52...
# 7               62  http://elblog.ecminteriorismo.com/2010/10/intr...
# 8              822  https://www.paisajetransversal.org/2015/09/har...
# 9              714  https://www.delosriosarquitectos.com/diario-ab...
# 10             768  https://www.librosarquitecturaonline.es/libros...
# 11             753  https://www.delosriosarquitectos.com/arquitect...
# 12              67  http://diariodesign.com/2017/07/contenedor-luj...
# 13             759  https://www.homify.com.mx/profesionales/arquit...
# 14             477  https://colombianewyork.com/el-arquitecto-colo...
# 15             768  https://www.kelosa.com/blog/es/arquitectos/jos...
# 16             644      https://www.arquine.com/casa-ia-landinez-rey/
# 17             285  http://www.arquitecturayempresa.es/noticia/eng...
# 18              60  http://diariodesign.com/2014/06/austin-contain...
# 19             848  https://www.plataformaarquitectura.cl/cl/87848...
# 20             705  https://www.archdaily.co/co/02-317498/hegel-51...
# 21             304  http://www.gpc.com.ar/index.php/es/biblioteca/...
# 22             615  https://perfectoambiente.com/2011/06/estanteri...
# 23             799  https://www.plataformaarquitectura.cl/cl/87233...
# 24             695  https://www.disenoyarquitectura.net/2011/12/kl...
# 25             834  https://www.plataformaarquitectura.cl/cl/02-34...
# 26              45               http://cgaleno.blogspot.com/2017/04/
# 27             207  http://www.arquitecturayempresa.es/noticia/arq...
# 28             218  http://smart-cities.euroresidentes.com/2012/07...
# 29             708     https://www.cosasdearquitectos.com/tag/jardin/
# ...            ...                                                ...
# 178750         108  http://inafocam.edu.do/transparencia/index.php...
# 178751          82  http://finanzasparatodos.es/es/economiavida/pl...
# 178752         510  https://es.talkingofmoney.com/setting-retireme...
# 178753          62  http://docentesdecanarias.org/dci/index.php/ju...
# 178754         638            https://www.abogadosnr.com/jubilaciones
# 178755         667  https://www.csif.es/contenido/castilla-y-leon/...
# 178756           4  http://afindemes.republica.com/finanzas/los-ju...
# 178757          96  http://finanzasparatodos.es/es/economiavida/pl...
# 178758          81  http://fmbolivia.com.bo/al-menos-45-trabajador...
# 178759         171  http://primerolafamilia.com/aprendiendo-a-enve...
# 178760         510   https://jubipen.com/tag/aumento-septiembre-2018/
# 178761         508                       https://jubipen.com/2018/05/
# 178762          95  http://finanzasparatodos.es/es/economiavida/pl...
# 178763         209  http://mundogerencial.net/formulario-fuerzas-c...
# 178764         672  https://www.definicionabc.com/general/anciano.php
# 178765         107  http://finanzasparatodos.es/es/economiavida/pl...
# 178766         759  https://www.elobservador.com.uy/nota/jubilacio...
# 178767         727  https://www.goya.gob.ar/?q=direccion-obras-par...
# 178768         790       https://www.lexdir.com/temas/jubilacion-719/
# 178769         384  http://www.the-sos.com/clave/Edad+jubilaci%26o...
# 178770          91  http://finanzasparatodos.es/es/economiavida/pl...
# 178771         778  https://www.latimes.com/espanol/eeuu/la-los-ba...
# 178772         829    https://www.tmrs.com/faq_members_en_espanol.php
# 178773         858  https://www.taxslayerpro.com/kb/686/Maximum-Pe...
# 178774         529       https://jubipen.com/tag/sistema-jubilatorio/
# 178775         837  https://www.taxslayerpro.com/kb/KnowledgebaseA...
# 178776         511   https://faq.ssa.gov/es-ES/Topic/article/KA-01897
# 178777         697  https://www.definicionabc.com/social/jubilacio...
# 178778         790  https://www.taxslayerpro.com/kb/378/Reporting-...
# 178779         110  http://gerontologia.maimonides.edu/2011/01/est...
#
#                                                     title  \
# 0                   Cómo pintar sobre cuero - Arquimaster
# 1       \nDipoli - Edificio Principal de la Universida...
# 2       Paisaje Transversal Blog: #EncuentrosASA_Roca:...
# 3       \nCasa Bromelia / Urban Recycle Architecture S...
# 4       \nLos Museos Guggenheim: polémicas arquitectón...
# 5       \nCómo se construyeron los muros inclinados y ...
# 6       \nInstituto Docet / stación-ARquitectura Arqui...
# 7              ECMInteriorismo: INTRODUCCION AL FENG SHUI
# 8       Paisaje Transversal Blog: #HarineraZGZ: Partic...
# 9       El diario ABC entrevista a De Los Ríos Arquite...
# 10      LibrerÃ­a  arquitectura, urbanismo y jardinerÃ...
# 11      Residencia de estudiantes Sevilla - Arquitecto...
# 12      Contenedor de lujo para Apple en Nueva York. -...
# 13      Arquitectos en Distrito Federal : Encuentra Ar...
# 14      Colombia New York -   Colombiano Carlos Arnaiz...
# 15           Josep Lluís Sert y el grupo GATEPAC | Kelosa
# 16                                      Casa iA | Arquine
# 17      English Style, vivienda victoriana actualizada...
# 18      Austin Container Bar: contenedores y muebles d...
# 19      \n#ConversacionesFAU 6: DelCampo-Labbé Arquite...
# 20      \nHegel 516 / FRB Arquitectura  | ArchDaily Co...
# 21                   11 Arquitectos argentinos destacados
# 22                        Estanterías modernas de Estar •
# 23      \nVIET Mi Oficina / TNT architects | Plataform...
# 24         \nKlein Bottle House de McBride Charles Ryan\n
# 25      \nDentro del Paisaje / Studio x Architettura |...
# 26      ARTE Y ARQUITECTURA (ART AND ARCHITECTURE): ab...
# 27      Arquitectura verde de altura, el bosque vertic...
# 28      Observatorio de Smart Cities: Ciudades intelig...
# 29                jardin etiquetas | COSAS de ARQUITECTOS
# ...                                                   ...
# 178750  Instituto Nacional de Formación y Capacitación...
# 178751  Estimar las otras fuentes de ingresos que le p...
# 178752  Estableciendo Objetivos de Retiro: ¿Cuál es su...
# 178753                                         Jubilación
# 178754  TE AYUDAMOS CON JUBILACIONES Y PENSIONES | NR ...
# 178755  Castilla y León Educación - CSIF INFORMA: Pens...
# 178756  Los jubilados del baby boom serán el gran reto...
# 178757                           Prepárese para el futuro
# 178758  Al menos 45 trabajadores del Servicio de Camin...
# 178759  Un Poco De Conocimiento Para Averiguar Acerca ...
# 178760  Aumento Septiembre 2018 | Jubilaciones y Pensi...
# 178761  mayo | 2018 | Jubilaciones y Pensiones en Arge...
# 178762  ¿Cómo recuperar el tiempo perdido si ha empeza...
# 178763   Formulario Fuerzas Comerciales – Mundo Gerencial
# 178764   Definición de Anciano » Concepto en Definició...
# 178765                    El plan de pensiones individual
# 178766  Jubilaciones: reforma inminente en Brasil y en...
# 178767                Dirección Obras Particulares | Goya
# 178768      Información legal y abogados sobre Jubilación
# 178769                   Edad jubilación - The-sos Buscar
# 178770  Calcule cuánto dinero necesitará al mes despué...
# 178771  Los baby boomers se jubilan en masa; hay tres ...
# 178772               TMRS • Resumen de Beneficios de TMRS
# 178773  Contribuciones Máximas de Planes de Pensión Kn...
# 178774  Sistema jubilatorio | Jubilaciones y Pensiones...
# 178775  Contribuciones Máximas de Planes de Pensión Kn...
# 178776  \n\t¿Cuál es la cantidad mensual máxima del be...
# 178777   Definición de Jubilación » Concepto en Defini...
# 178778                      Reportar un IRA Knowledgebase
# 178779  Estirar los ahorros: Los baby boomers preparan...
#
#                                            extracted_text  \
# 0       Principal Contacto | Publicidad Publicar | Sub...
# 1       Perú Brasil China Colombia Hispanoamérica Méxi...
# 2       #EncuentrosASA_Roca: Un mundo de ciudades Hoy ...
# 3       Hispanoamérica Brasil China Colombia México Pe...
# 4       Documentos Planos Textos Multimedia Proyectos ...
# 5       México Brasil China Colombia Hispanoamérica Pe...
# 6       Hispanoamérica Brasil China Colombia México Pe...
# 7       ECMInteriorismo IN&OUT GALLERY - ideas decorac...
# 8       #HarineraZGZ: Participación ciudadana para rev...
# 9       Estudio Arquitectura en Cadiz Llamar ahora! +3...
# 10      CONTÁCTENOS - 91 575 78 24 91 575 78 24 www.li...
# 11      Estudio Arquitectura en Cadiz Llamar ahora! +3...
# 12      Si, nosotros también usamos cookies. Esas cosa...
# 13      Arquitectos en Distrito Federal : Encuentra Ar...
# 14      Inicio Ciencia/Tecnologia/Arquitectura Empresa...
# 15      Monday / Mar 18 / 2019 Agencia Inmobiliaria | ...
# 16      Arquine PUBLICA CONVOCA VENDE Buscar: Enviar o...
# 17      Pasar al contenido principal Toggle Menu secci...
# 18      Si, nosotros también usamos cookies. Esas cosa...
# 19      Hispanoamérica Brasil China Colombia México Pe...
# 20      Colombia Brasil China Hispanoamérica México Pe...
# 21      Biblioteca Buscar... Recursos Índices y precio...
# 22      Inicio Contacto Decoración • Diseño • Arquitec...
# 23      Hispanoamérica Brasil China Colombia México Pe...
# 24      Página principal Contacto ▷ Revista Arquitectu...
# 25      Hispanoamérica Brasil China Colombia México Pe...
# 26      ARTE Y ARQUITECTURA (ART AND ARCHITECTURE) Por...
# 27      Pasar al contenido principal Toggle Menu secci...
# 28      Páginas Página principal Proyecto Proyectos de...
# 29      COSAS de ARQUITECTOS revista digital de arquit...
# ...                                                   ...
# 178750  Inicio Mapa de sitio Contacto Menú Inicio Inst...
# 178751  Accesibilidad Mapa web Contacto RSS Idioma: Es...
# 178752  Home Artículos Invertir Condiciones Comercio T...
# 178753  DOCENTES DE CANARIAS-INSUCAN (DCI) email: doce...
# 178754  Chat with us , powered by LiveChat NOTICIAS PR...
# 178755  Pasar al contenido principal Nacional Acción S...
# 178756  Republica.com Ahorro Empleo Economía y finanza...
# 178757  Accesibilidad Mapa web Contacto RSS Idioma: Es...
# 178758  lunes, 18 de marzo de 2019 - 11:27 Última: Ide...
# 178759  Un Poco De Conocimiento Para Averiguar Acerca ...
# 178760  Jubilaciones y Pensiones en Argentina Blog ela...
# 178761  Jubilaciones y Pensiones en Argentina Blog ela...
# 178762  Accesibilidad Mapa web Contacto RSS Idioma: Es...
# 178763  INSCRIPCIÓN TALLER FUERZAS COMERCIALES Datos d...
# 178764  Definición ABC General » Anciano Definición de...
# 178765  Accesibilidad Mapa web Contacto RSS Idioma: Es...
# 178766  Portada Nacional Economía y empresas Referí - ...
# 178767  Ir al contenido principal Goya Mostrar/Ocultar...
# 178768  BUSCA información legal Nuevas tecnologías Imp...
# 178769  The-sos Buscar Para que usted pueda encontrar ...
# 178770  Accesibilidad Mapa web Contacto RSS Idioma: Es...
# 178771  Skip to content Topics xml:space="preserve"> H...
# 178772  Texas Municipal Retirement System Texas Munici...
# 178773  MY ACCOUNT LOGIN Change Language English Spani...
# 178774  Jubilaciones y Pensiones en Argentina Blog ela...
# 178775  MY ACCOUNT LOGIN Change Language English Spani...
# 178776  Pase al contenido Seguro Social Menú Ingresar*...
# 178777  Definición ABC Social » Jubilación Definición ...
# 178778  MY ACCOUNT LOGIN Change Language English Spani...
# 178779  Ciencias del Envejecimiento – Gerontología – U...
#
#                              predicted_class  confidence
# 0                  architecture-architecture        0.85
# 1                  architecture-architecture        0.85
# 2                  architecture-architecture        0.85
# 3                  architecture-architecture        0.85
# 4                  architecture-architecture        0.85
# 5                  architecture-architecture        0.85
# 6                  architecture-architecture        0.85
# 7                  architecture-architecture        0.85
# 8                  architecture-architecture        0.85
# 9                  architecture-architecture        0.85
# 10                 architecture-architecture        0.85
# 11                 architecture-architecture        0.85
# 12                 architecture-architecture        0.85
# 13                 architecture-architecture        0.85
# 14                 architecture-architecture        0.85
# 15                 architecture-architecture        0.85
# 16                 architecture-architecture        0.85
# 17                 architecture-architecture        0.85
# 18                 architecture-architecture        0.85
# 19                 architecture-architecture        0.85
# 20                 architecture-architecture        0.85
# 21                 architecture-architecture        0.85
# 22                 architecture-architecture        0.85
# 23                 architecture-architecture        0.85
# 24                 architecture-architecture        0.85
# 25                 architecture-architecture        0.85
# 26                 architecture-architecture        0.85
# 27                 architecture-architecture        0.85
# 28                 architecture-architecture        0.85
# 29                 architecture-architecture        0.85
# ...                                      ...         ...
# 178750  personal finance-retirement planning        0.30
# 178751  personal finance-retirement planning        0.30
# 178752  personal finance-retirement planning        0.30
# 178753  personal finance-retirement planning        0.30
# 178754  personal finance-retirement planning        0.30
# 178755  personal finance-retirement planning        0.30
# 178756  personal finance-retirement planning        0.30
# 178757  personal finance-retirement planning        0.35
# 178758  personal finance-retirement planning        0.35
# 178759  personal finance-retirement planning        0.35
# 178760  personal finance-retirement planning        0.35
# 178761  personal finance-retirement planning        0.35
# 178762  personal finance-retirement planning        0.35
# 178763  personal finance-retirement planning        0.35
# 178764  personal finance-retirement planning        0.35
# 178765  personal finance-retirement planning        0.35
# 178766  personal finance-retirement planning        0.35
# 178767  personal finance-retirement planning        0.40
# 178768  personal finance-retirement planning        0.40
# 178769  personal finance-retirement planning        0.40
# 178770  personal finance-retirement planning        0.40
# 178771  personal finance-retirement planning        0.40
# 178772  personal finance-retirement planning        0.45
# 178773  personal finance-retirement planning        0.45
# 178774  personal finance-retirement planning        0.45
# 178775  personal finance-retirement planning        0.45
# 178776  personal finance-retirement planning        0.45
# 178777  personal finance-retirement planning        0.50
# 178778  personal finance-retirement planning        0.55
# 178779  personal finance-retirement planning        0.90
#
# [178780 rows x 6 columns]

# %%
original_df['subcategory'] = original_df['predicted_class']

# %%
original_df['category'] = [subcat.split('-')[0] for subcat in original_df['subcategory']]

# %%
sorted(pd.unique(original_df['subcategory']))
# Out:
# ['architecture-architecture',
#  'arts & entertainment-animation',
#  'arts & entertainment-anime',
#  'arts & entertainment-arts & entertainment',
#  'arts & entertainment-celebrities',
#  'arts & entertainment-comics',
#  'arts & entertainment-design',
#  'arts & entertainment-film',
#  'arts & entertainment-humor',
#  'arts & entertainment-literature',
#  'arts & entertainment-music',
#  'arts & entertainment-opera',
#  'arts & entertainment-poetry',
#  'arts & entertainment-radio',
#  'arts & entertainment-television',
#  'arts & entertainment-video games',
#  'automotive-automotive',
#  'automotive-car brands',
#  'automotive-motorcycles',
#  'automotive-pickup trucks',
#  'business-advertising',
#  'business-biotech',
#  'business-business',
#  'business-ecommerce',
#  'business-energy',
#  'business-marketing',
#  'careers-careers',
#  'cell phones-cell phones',
#  'drugs-drugs',
#  'education-academia',
#  'education-education',
#  'education-homeschooling',
#  'family & parenting-parenting',
#  'family & parenting-pregnancy',
#  'fashion-beauty',
#  'fashion-body art',
#  'fashion-clothing',
#  'fashion-fashion',
#  'fashion-jewelry',
#  'folklore-astrology',
#  'folklore-folklore',
#  'folklore-paranormal phenomena',
#  'food & drink-baking',
#  'food & drink-barbecues & grilling',
#  'food & drink-beer',
#  'food & drink-cheese',
#  'food & drink-cider',
#  'food & drink-cocktails',
#  'food & drink-coffee',
#  'food & drink-cooking',
#  'food & drink-food & drink',
#  'food & drink-pasta',
#  'food & drink-tea',
#  'food & drink-vegan',
#  'food & drink-vegetarian',
#  'food & drink-wine',
#  'health & fitness-aids hiv',
#  'health & fitness-alternative medicine',
#  'health & fitness-anatomy',
#  'health & fitness-asthma',
#  'health & fitness-autism',
#  'health & fitness-cancer',
#  'health & fitness-cardiac',
#  'health & fitness-chronic pain',
#  'health & fitness-deafness',
#  'health & fitness-dental care',
#  'health & fitness-depression',
#  'health & fitness-dermatology',
#  'health & fitness-diabetes',
#  'health & fitness-dieting',
#  'health & fitness-epilepsy',
#  'health & fitness-exercise',
#  'health & fitness-health & fitness',
#  'health & fitness-nutrition',
#  'health & fitness-pediatrics',
#  'health & fitness-psychology & psychiatry',
#  'health & fitness-sex',
#  'health & fitness-stress',
#  'history-archaeology',
#  'history-history',
#  'hobbies & interests-antiques',
#  'hobbies & interests-arts & crafts',
#  'hobbies & interests-board games',
#  'hobbies & interests-coins',
#  'hobbies & interests-dance',
#  'hobbies & interests-gambling',
#  'hobbies & interests-genealogy',
#  'hobbies & interests-hobbies & interests',
#  'hobbies & interests-horse racing',
#  'hobbies & interests-needlework',
#  'hobbies & interests-photography',
#  'hobbies & interests-sci-fi',
#  'hobbies & interests-scouting',
#  'hobbies & interests-smoking',
#  'hobbies & interests-writing',
#  'home-appliances',
#  'home-garden',
#  'home-home',
#  'home-interior design',
#  'law-crime',
#  'law-immigration',
#  'law-law',
#  'military-military',
#  'personal finance-banking',
#  'personal finance-credit & debt & loans',
#  'personal finance-insurance',
#  'personal finance-investing',
#  'personal finance-personal finance',
#  'personal finance-retirement planning',
#  'personal finance-tax',
#  'pets-aquariums',
#  'pets-birds',
#  'pets-cats',
#  'pets-dogs',
#  'pets-pets',
#  'politics-politics',
#  'real estate-mortgages',
#  'real estate-real estate',
#  'religion-buddhism',
#  'religion-christianity',
#  'religion-hinduism',
#  'religion-islam',
#  'religion-judaism',
#  'religion-religion',
#  'science-astronomy',
#  'science-biology',
#  'science-botany',
#  'science-chemistry',
#  'science-economics',
#  'science-geography',
#  'science-geology',
#  'science-mathematics',
#  'science-mechanics',
#  'science-palaeontology',
#  'science-physics',
#  'science-science',
#  'society-anthropology',
#  'society-dating',
#  'society-gay life',
#  'society-marriage',
#  'society-social networking',
#  'society-society',
#  'society-sociology',
#  'sports-american football',
#  'sports-archery',
#  'sports-athletics',
#  'sports-baseball',
#  'sports-basketball',
#  'sports-bodybuilding',
#  'sports-bowling',
#  'sports-boxing',
#  'sports-climbing',
#  'sports-cricket',
#  'sports-cycling',
#  'sports-diving',
#  'sports-fishing',
#  'sports-golf',
#  'sports-hockey',
#  'sports-hunting',
#  'sports-jogging',
#  'sports-martial arts',
#  'sports-olympics',
#  'sports-racing',
#  'sports-rugby',
#  'sports-sailing',
#  'sports-skateboarding',
#  'sports-skiing',
#  'sports-snowboarding',
#  'sports-soccer',
#  'sports-sports',
#  'sports-surfing',
#  'sports-swimming',
#  'sports-tennis',
#  'sports-volleyball',
#  'sports-wrestling',
#  'sports-yoga',
#  'technology & computing-apple',
#  'technology & computing-database',
#  'technology & computing-freeware',
#  'technology & computing-gaming',
#  'technology & computing-programming',
#  'technology & computing-software',
#  'technology & computing-technology & computing',
#  'technology & computing-unix',
#  'technology & computing-windows',
#  'travel-adventure travel',
#  'travel-air travel',
#  'travel-hotels',
#  'travel-travel',
#  'weather-weather']

# %%
extracted_categories = set()
def extract_category(df, category):
    extracted = df[df['subcategory']==category]
    return extracted
def relabel_df(df, subcategory, category = None):
    l = len(df)
    subcategories = [subcategory for i in range(l)]
    df['subcategory'] = subcategories
    if category!=None:
        categories = [category for i in range(l)]
        df['category'] = categories

# %%
nuke_cats = ['arts & entertainment-celebrities',
 'arts & entertainment-humor',
 'business-advertising',
 'business-biotech',
 'business-ecommerce',
 'computing-freeware',
 'drugs-drugs',
 'fashion-body art',
 'health & fitness-aids hiv',
 'health & fitness-anatomy',
 'health & fitness-asthma',
 'health & fitness-autism',
 'health & fitness-cancer',
 'health & fitness-cardiac',
 'health & fitness-chronic pain',
 'health & fitness-deafness',
 'health & fitness-depression',
 'health & fitness-dermatology',
 'health & fitness-diabetes',
 'health & fitness-epilepsy',
 'health & fitness-health & fitness',
 'health & fitness-pediatrics',
 'health & fitness-psychology & psychiatry',
 'health & fitness-stress',
 'law-crime',
 'law-immigration',
 'politics-politics',
 'religion-religion',
 'religion-buddhism',
 'religion-christianity',
 'religion-hinduism',
 'religion-islam',
 'religion-judaism',
 'society-anthropology',
 'society-dating',
 'society-gay life',
 'society-marriage',
 'society-social networking',
 'society-society',
 'society-sociology']

merge_cats = ['arts & entertainment-video games',
'technology & computing-gaming',
'health & fitness-dieting',
'health & fitness-nutrition',
'home-garden',
'science-botany',
'automotive-automotive',
'automotive-car brands',
 ]

 
more_gambling_urls = set(['http://poker.stackexchange.com/', 'http://www.pokerrules.net/', 
'http://poker.stackexchange.com/', 'http://www.blackjackrules.org/'])

# %%
nuke_dfs = {}
for nuke_cat in nuke_cats:
    nuke_dfs[nuke_cat] = extract_category(original_df, nuke_cat)

merge_dfs = {}
for merge_cat in merge_cats:
    merge_dfs[merge_cat] = extract_category(original_df, merge_cat)

# %%
# Remove gambling related card games
additional_gambling = original_df[original_df['url'].isin(more_gambling_urls)]
# relabel body-building
body_building_df = original_df[original_df['subcategory']=='sports-bodybuilding']

#clean up original_df
cleaner_df = original_df[original_df['subcategory']!='sports-bodybuilding']
cleaner_df = cleaner_df[cleaner_df['url'].isin(more_gambling_urls)==False]
cleaner_df = cleaner_df[cleaner_df['subcategory'].isin( set(nuke_dfs.keys()) ) == False]
cleaner_df = cleaner_df[cleaner_df['subcategory'].isin( set(merge_dfs.keys()) ) == False]

# %%
len(cleaner_df)
# Out:
# 134604

# %%
# merge & move categories:

gaming_df = pd.concat([ merge_dfs['arts & entertainment-video games'], merge_dfs['technology & computing-gaming'] ])
diet_nutrition_df = pd.concat([ merge_dfs['health & fitness-dieting'], merge_dfs['health & fitness-nutrition'] ])
garden_df = pd.concat([ merge_dfs['home-garden'], merge_dfs['science-botany']])
auto_df = pd.concat([ merge_dfs['automotive-automotive'],merge_dfs['automotive-car brands'] ])
other_df = pd.concat(list(nuke_dfs.values()))
# relabel: 
relabel_df(diet_nutrition_df, 'health & fitness-diet & nutrition')
relabel_df(garden_df, 'home-garden', category='home')
relabel_df(gaming_df, 'gaming-gaming',category='gaming')
relabel_df(auto_df, 'automotive-automotive')
relabel_df(body_building_df, 'health & fitness-bodybuilding', 'health & fitness')
relabel_df(additional_gambling,  'hobbies & interests-gambling')
relabel_df(other_df, 'other-other', 'other')
# Out:
# /home/dimmu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/dimmu/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
new_taxonomy_df = pd.concat([cleaner_df, diet_nutrition_df, garden_df, gaming_df, body_building_df, additional_gambling, other_df])

# %%
len(new_taxonomy_df)
# Out:
# 176780

# %%
sorted(pd.unique(new_taxonomy_df['category']))
# Out:
# ['architecture',
#  'arts & entertainment',
#  'automotive',
#  'business',
#  'careers',
#  'cell phones',
#  'education',
#  'family & parenting',
#  'fashion',
#  'folklore',
#  'food & drink',
#  'gaming',
#  'health & fitness',
#  'history',
#  'hobbies & interests',
#  'home',
#  'law',
#  'military',
#  'other',
#  'personal finance',
#  'pets',
#  'real estate',
#  'science',
#  'sports',
#  'technology & computing',
#  'travel',
#  'weather']

# %%
sorted(pd.unique(new_taxonomy_df['subcategory']))
# Out:
# ['architecture-architecture',
#  'arts & entertainment-animation',
#  'arts & entertainment-anime',
#  'arts & entertainment-arts & entertainment',
#  'arts & entertainment-comics',
#  'arts & entertainment-design',
#  'arts & entertainment-film',
#  'arts & entertainment-literature',
#  'arts & entertainment-music',
#  'arts & entertainment-opera',
#  'arts & entertainment-poetry',
#  'arts & entertainment-radio',
#  'arts & entertainment-television',
#  'automotive-motorcycles',
#  'automotive-pickup trucks',
#  'business-business',
#  'business-energy',
#  'business-marketing',
#  'careers-careers',
#  'cell phones-cell phones',
#  'education-academia',
#  'education-education',
#  'education-homeschooling',
#  'family & parenting-parenting',
#  'family & parenting-pregnancy',
#  'fashion-beauty',
#  'fashion-clothing',
#  'fashion-fashion',
#  'fashion-jewelry',
#  'folklore-astrology',
#  'folklore-folklore',
#  'folklore-paranormal phenomena',
#  'food & drink-baking',
#  'food & drink-barbecues & grilling',
#  'food & drink-beer',
#  'food & drink-cheese',
#  'food & drink-cider',
#  'food & drink-cocktails',
#  'food & drink-coffee',
#  'food & drink-cooking',
#  'food & drink-food & drink',
#  'food & drink-pasta',
#  'food & drink-tea',
#  'food & drink-vegan',
#  'food & drink-vegetarian',
#  'food & drink-wine',
#  'gaming-gaming',
#  'health & fitness-alternative medicine',
#  'health & fitness-bodybuilding',
#  'health & fitness-dental care',
#  'health & fitness-diet & nutrition',
#  'health & fitness-exercise',
#  'health & fitness-sex',
#  'history-archaeology',
#  'history-history',
#  'hobbies & interests-antiques',
#  'hobbies & interests-arts & crafts',
#  'hobbies & interests-board games',
#  'hobbies & interests-coins',
#  'hobbies & interests-dance',
#  'hobbies & interests-gambling',
#  'hobbies & interests-genealogy',
#  'hobbies & interests-hobbies & interests',
#  'hobbies & interests-horse racing',
#  'hobbies & interests-needlework',
#  'hobbies & interests-photography',
#  'hobbies & interests-sci-fi',
#  'hobbies & interests-scouting',
#  'hobbies & interests-smoking',
#  'hobbies & interests-writing',
#  'home-appliances',
#  'home-garden',
#  'home-home',
#  'home-interior design',
#  'law-law',
#  'military-military',
#  'other-other',
#  'personal finance-banking',
#  'personal finance-credit & debt & loans',
#  'personal finance-insurance',
#  'personal finance-investing',
#  'personal finance-personal finance',
#  'personal finance-retirement planning',
#  'personal finance-tax',
#  'pets-aquariums',
#  'pets-birds',
#  'pets-cats',
#  'pets-dogs',
#  'pets-pets',
#  'real estate-mortgages',
#  'real estate-real estate',
#  'science-astronomy',
#  'science-biology',
#  'science-chemistry',
#  'science-economics',
#  'science-geography',
#  'science-geology',
#  'science-mathematics',
#  'science-mechanics',
#  'science-palaeontology',
#  'science-physics',
#  'science-science',
#  'sports-american football',
#  'sports-archery',
#  'sports-athletics',
#  'sports-baseball',
#  'sports-basketball',
#  'sports-bowling',
#  'sports-boxing',
#  'sports-climbing',
#  'sports-cricket',
#  'sports-cycling',
#  'sports-diving',
#  'sports-fishing',
#  'sports-golf',
#  'sports-hockey',
#  'sports-hunting',
#  'sports-jogging',
#  'sports-martial arts',
#  'sports-olympics',
#  'sports-racing',
#  'sports-rugby',
#  'sports-sailing',
#  'sports-skateboarding',
#  'sports-skiing',
#  'sports-snowboarding',
#  'sports-soccer',
#  'sports-sports',
#  'sports-surfing',
#  'sports-swimming',
#  'sports-tennis',
#  'sports-volleyball',
#  'sports-wrestling',
#  'sports-yoga',
#  'technology & computing-apple',
#  'technology & computing-database',
#  'technology & computing-freeware',
#  'technology & computing-programming',
#  'technology & computing-software',
#  'technology & computing-technology & computing',
#  'technology & computing-unix',
#  'technology & computing-windows',
#  'travel-adventure travel',
#  'travel-air travel',
#  'travel-hotels',
#  'travel-travel',
#  'weather-weather']

# %%
# we should observe a substantial reduction to the number of subcategories
len(pd.unique(new_taxonomy_df['subcategory']))
# Out:
# 147

# %%
#write this to disk
new_taxonomy_df.to_csv('es_taxonomyV0.2.csv.gz', index=False, compression='gzip')
